# %%
from ultralytics import YOLO
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from ultralytics import YOLO
#
# ModuleNotFoundError: No module named 'ultralytics'

# %%
model = YOLO('yolov8l.pt') # pass any model type

# %%
model.val()  # It'll automatically evaluate the data you trained.
# Out:
# Ultralytics YOLOv8.0.182  Python-3.10.11 torch-2.0.1+cpu CPU (AMD Ryzen 9 7900X 12-Core Processor)
# YOLOv8l summary (fused): 268 layers, 43668288 parameters, 0 gradients
#
# Dataset 'coco.yaml' images not found , missing path 'C:\Users\Hyunwoo\Documents\Pyproject\SoccerTrackingAnalysis\datasets\coco\val2017.txt'
# ...
# 100%|██████████| 169M/169M [00:04<00:00, 36.8MB/s]
# Unzipping C:\Users\Hyunwoo\Documents\Pyproject\SoccerTrackingAnalysis\datasets\coco2017labels-segments.zip to C:\Users\Hyunwoo\Documents\Pyproject\SoccerTrackingAnalysis\datasets\coco...: 100%|██████████| 122232/122232 [00:56<00:00, 2180.19file/s]
# ...

# %%
model.to('cuda')
# Out:
# Ultralytics YOLOv8.0.180 🚀 Python-3.10.11 torch-2.0.1 CPU (Apple M1 Pro)
# ...

# %%
results =model.track(source="https://youtube.com/clip/Ugkx1zgDtCWV5GQETmV9XCY6-NEsnupfXRGi?si=vz_6bdRZ3NienKrR", tracker="botsort.yaml")
# Out:
# 1/1: https://youtube.com/clip/Ugkx1zgDtCWV5GQETmV9XCY6-NEsnupfXRGi?si=vz_6bdRZ3NienKrR... Success ✅ (149413 frames of shape 1920x1080 at 25.00 FPS)
#
#
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# 0: 384x640 1 person, 342.7ms
# 0: 384x640 24 persons, 267.8ms
# 0: 384x640 9 persons, 312.3ms
# 0: 384x640 14 persons, 267.6ms
# 0: 384x640 15 persons, 253.4ms
# 0: 384x640 15 persons, 245.0ms
# 0: 384x640 13 persons, 278.5ms
# 0: 384x640 15 persons, 236.8ms
# ...
